# %% [markdown]
# ## Introduction to Stats in Python Studio
#
# We are going to be working with this [dataset](https://www.kaggle.com/andrewmvd/heart-failure-clinical-data) from Kaggle.  No need to download, as it is included in the git repository you just cloned.
# <br>
#
# Heart Disease is the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide.
# <br>
#
# Heart failure is a common event caused by heart disease and this dataset contains 12 features that can be used to predict mortality by heart failure. You are tasked to look at two particular variables and record your observations about their usefulness for predicting the probability of heart failure.
# <br>
#
# In section one, you will be asked to run some simple EDA and apply statistical terminology to describe each variable in more detail.  Section two will explore what the distribution of your variables looks like. Finally, in section three you will be asked to make some inferences about your variables and if you feel they are good indicators of predicting heart failure.
# <br>
#
# Answer the questions and record your observations in the space provided. Feel free to add more code blocks if you'd like.
# <br>

# %% [raw]
# Description of Data:
#
# Sex - Gender of patient Male = 1, Female =0
# Age - Age of patient
# Diabetes - 0 = No, 1 = Yes
# Anaemia - 0 = No, 1 = Yes
# High_blood_pressure - 0 = No, 1 = Yes
# Smoking - 0 = No, 1 = Yes
# DEATH_EVENT - 0 = No, 1 = Yes

# %%
# Import libries need with alias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')


# Set style and font size
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# Read in data to a dataframe
df = pd.read_csv('heart3.csv')

# %% [markdown]
# ## Section 1: First look at the data:
#
# Run some simple EDA and look at the data and your variables. Answer the following questions.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe().round(2)
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# count  299.00   299.00                    299.00    299.00             299.00
# mean    60.83     0.43                    581.84      0.42              38.08
# std     11.89     0.50                    970.29      0.49              11.83
# min     40.00     0.00                     23.00      0.00              14.00
# 25%     51.00     0.00                    116.50      0.00              30.00
# 50%     60.00     0.00                    250.00      0.00              38.00
# 75%     70.00     1.00                    582.00      1.00              45.00
# max     95.00     1.00                   7861.00      1.00              80.00
#
#        high_blood_pressure  platelets  serum_creatinine  serum_sodium     sex  \
# count               299.00     299.00            299.00        299.00  299.00
# mean                  0.35  263358.03              1.39        136.63    0.65
# std                   0.48   97804.24              1.03          4.41    0.48
# min                   0.00   25100.00              0.50        113.00    0.00
# 25%                   0.00  212500.00              0.90        134.00    0.00
# 50%                   0.00  262000.00              1.10        137.00    1.00
# 75%                   1.00  303500.00              1.40        140.00    1.00
# max                   1.00  850000.00              9.40        148.00    1.00
#
#        smoking    time  DEATH_EVENT
# count   299.00  299.00       299.00
# mean      0.32  130.26         0.32
# std       0.47   77.61         0.47
# min       0.00    4.00         0.00
# 25%       0.00   73.00         0.00
# 50%       0.00  115.00         0.00
# 75%       1.00  203.00         1.00
# max       1.00  285.00         1.00

# %% [markdown]
# Which of our columns are catogorical data?<BR><BR><BR>
# age, anaemia, DEATH_EVENT, diabetes, high_blood_pressure, sex, smoking
#
# Which of our columns are continuous?<BR><BR><BR>
# creatinine_phosphokinase, ejection_fraction, platelets, serum_creatinine, serum_sodim, time

# %% [markdown]
# ### Statistical interpretation of our data?
# #### First Variable: Age
# Mean, Min, Max, STD? Describe what this means <br>
# Mean: 60.83 (the average age of population) <br>
# Min: 40.00 (the youngest age of population) <br>
# Max: 95.00 (the oldest age of population)<br>
# Std: 11.89 (a measure of how dispersed the data is in relation to the mean)
#
# <br><br><br>
#
#
# #### Second Variable: Platelets
# Mean, Min, Max, STD? Describe what this means. <br>
# Mean: 263358.03 (the average number of platelets in the blood) <br>
# Min: 25100.00 (the lowest number of platelets in the blood) <br>
# Max: 850000.00 (the largest number of platelets in the blood) <br>
# Std: 97804.24	(a measure of how disperesed the data is in relation to the mean)
#
# <br><br><br>
#
# What could the numbers in our categorical data tell us?<br>
#
# <br><br><br>
#
# Why might we want to keep our categorical data as 1's and 0's? Why may we want to use something like the code below to change it?<br>
#
# We may want to keep our categorical data as 1's and 0's to keep our categorical data standard throughout.
# We may want to replace the 1's and 0's with labels to make it easier to read.

# %%
#df['sex'] = df.sex.replace({1: "Male", 0: "Female"})
#df['anaemia'] = df.anaemia.replace({1: "Yes", 0: "No"})
#df['diabetes'] = df.diabetes.replace({1: "Yes", 0: "No"})
#df['high_blood_pressure'] = df.high_blood_pressure.replace({1: "Yes", 0: "No"})
#df['smoking'] = df.smoking.replace({1: "Yes", 0: "No"})

#df['DEATH_EVENT'] = df.DEATH_EVENT.replace({1: "Died", 0: "Alive"})

# %% [markdown]
# ## Section 2: Distribution of our data:

# %%
# Plot the distribution of your variable using distplot
# age

sns.distplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
# Create boxplot to show distribution of variable
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2440fd0ad10>,
#   <matplotlib.lines.Line2D at 0x2440fd0afb0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2440fd0b250>,
#   <matplotlib.lines.Line2D at 0x2440fd0b4f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2440fd0aa70>],
#  'medians': [<matplotlib.lines.Line2D at 0x2440fd0b790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2440fd0ba30>],
#  'means': []}

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %%
# Another way to check the skewness of our variable
df['age'].skew()
# Out:
# 0.42306190672863536

# %%
# Another way to check the kurtosis of our variable
df['age'].kurtosis()
# Out:
# -0.18487053195417413

# %% [markdown]
# ### Interpretation of how our data is distributed by variable?
# Looking at the above graphs, what can you tell about the distribution of your variables?
# The age of our population is skewed to the right, there are more comparatively your people than old people.
# <br><br><br><br><br>
# What is the skewness and kurtosis of your variables.  What does this mean?<br>
# Our skewness is 0.42. Since the number is positive, our data is skewed to the right, and since it is near .5, our data is moderately skewed. Our kurtosis is -0.18. Since this number is near 0, our data is near symetrical.
# <br><br><br><br><br>
# What are some of the differences you note looking at a categorical variable vs a continuous variable?
# <br><br><br><br><br>

# %% [markdown]
# ## Section 3: Finding Correlations
#
# Lets start by breaking our data into two.

# %%
# splitting the dataframe into 2 parts
# on basis of ‘DEATH_EVENT’ column values
df_died = df[df['DEATH_EVENT'] == 1 ]
df_lived = df[df['DEATH_EVENT'] == 0 ]

# %%
# Plot your variable based on if they died or lived

sns.distplot(df_died['age'])
sns.distplot(df_lived['age'])
plt.title("Chances of survival vs Variable")
plt.legend(('Died','Lived'))
plt.plot()
# Out:
# []

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %% [markdown]
# #### What things can you infer if we consider our data a sample of the population, based on each of your variables.
# <br>
# The older the popilation, the more likely they are to die from hear disease. <br><br><br><br>
# #### Do you think either of your variables is a good indicator for predicting Heart Failure, why or why not?
# <br>Age, on it's own, is not a great indicator of heart failure, due to the multitude of other factors that can cause heart failure and death. <br><br><br><br>
